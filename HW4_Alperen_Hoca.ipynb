# %% [markdown]
# ### 1) 100 katlı bina var 2 adet yumurta ile sadece tek sefer kullanmak şartı en az kaç defada yumurtanın kırılmadığı katı bulabiliriz?

# %% [markdown]
# ilk yumurtayı sırasıyla 20. kat, 40.kat, 60.kat ve 80. kattan atarız. Yumurtanın kırıldıysa kırıldığı kat ve 20 kat aşağısı arasında olacağını biliriz. sonrasında 2 arttırarak 2. yumurta ile ararız. Yani yumurta 100. katta kırılacaksa;
# 20-40-60-80-82-84-86-88-90-92-94-96-98-100 şeklinde bir deneme yaparız. En çok 14 aşamada sonucu öğreniriz.

# %% [markdown]
# ### 2) Görüntü işleme aşamlarını sırası ile tarif ediniz.

# %% [markdown]
# *   Input : Resmimizin ilk geldiği ve giriş bilgisi olarak tanımlandığı yer.
#
# *   Convolution Layer : Bu katman CNN'nin ana yapı taşıdır. Resmin özelliklerini algılamaktan sorumludur. Bu katman, görüntüdeki düşük ve yüksek seviyeli özellikleri çıkarmak için resme bazı fitreler uygular.
#
# *   ReLU Layer : ReLU fonksiyonu doğrultulmuş lineer birim (rectified linear unit- RELU) doğrusal olmayan bir fonksiyondur. ReLU fonksiyonu negatif girdiler için 0 değerini alırken, x pozitif girdiler için x değerini almaktadır. Convolution ve Poolig katmanlarıyla birlikte uygulanır.
#
# *   Pool Layer : Ağırlık sayısını azaltan ve uygunluğu kontrol eden katmandır.
#
# *   Fully Connected Layer : sinir ağına girecek bilgilerin hazır olduğu katmandır.

# %% [markdown]
# ### 3) Feature map veya bir sonraki layerın boyutlarını belirleyen özellikler nelerdir. Açıklayınız.

# %% [markdown]
# Feature mapın boyutunu input bilgisi ve kernel arasındaki bağıntı belirler. Örnek olarak 5x5 lik bir input ve 3x3 lük bir kernelimiz varsa feature mapimiz 3x3 lük olacaktır. Genel olarak boyutu etkileyen faktörler şunlardır.
#
# ● Kernel Size (K x K)
#
# ● Depth
#
# ● Stride
#
# ● Padding

# %% [markdown]
# ### 4) Softmax nedir? Ne işe yarar?

# %% [markdown]
# Softmax bir aktivasyon fonksiyonudur. Aktivasyon fonksiyonları sistemin nonlineerliğini arttırmak için kullanılan yöntemlerdir ve giriş bilgilerini 0 ila 1 arasına sıkıştırırlar.

# %% [markdown]
# ### 5) Aktivasyon fonskiyonlarının kullanım amaçları nedir? 3 adet örnek veriniz. Amaçlarını açıklayınız. Şekillerini  çiziniz.

# %% [markdown]
# Aktivasyon fonksiyonları yapay sinir ağlarında yapıları biraz daha analitik düşünmeye iten ezberbozduran yapılardır.
#
# *   tanh fonksiyonu
# *   softmax fonksiyonu
# *   sigmoid fonksiyonu

# %% [markdown]
# ![tanh.webp](data:image/webp;base64,...)

# %% [markdown]
# ![Screen_Shot_2020-05-23_at_11.56.35_PM_yh1VO82.png](data:image/png;base64,...)

# %% [markdown]
# ![1_Xu7B5y9gp0iL5ooBj7LtWw.png](data:image/png;base64,...)

# %% [markdown]
# ### 6) 32,32 lik image oldğunu düşünelim 2,2 like Max pooling sonucunda çıktı hangi boyutta olur?

# %% [markdown]
# 31x31 lik bir çıktı olur. ((32-2)/1)+1=31 olur.

# %% [markdown]
# ### 7) 6. soruya ek olarak eğer bu işlemler esnasında stride=2 olursa çıktı boyutu nasıl olur?

# %% [markdown]
# ((n-f)/s)+1 formülünü tekrar uyguladığımızda ((32-2)/2)+1= 16 olur. yani çıktımız 16x16 lık formata dönüşür.

# %% [markdown]
# ### 8) Droupout'un amacı nedir?

# %% [markdown]
# Eğitim sırasında aşırı öğrenmeyi(overfitting) engellemek için bazı nöronları unutmak için kullanılanılır.

# %% [markdown]
# ### 9) Görüntü işleme yöntemleri için kullanılan 3 adet framework belirtiniz.

# %% [markdown]
# En sık kullanılanlar: Tensorflow, derin öğrenme bazlı çalışmalarda bir numaradır. OpenCV, görüntü işlemede çokça kullanılır. Pillow'da  yeniden boyutlandırma, filtre ekleme ve daha fazlası gibi görüntüleri işlemek için birçok prosedür sağlar.

# %% [markdown]
# ### 10) Niçin imajlar için ANN yerine CNN kullanıyoruz?

# %% [markdown]
# Çünkü ANN kullanacaksak bile giriş bilgilerini matris formatında veremeyiz. Bu işin raconu bu.

# %% [markdown]
# ### 11) CNN ağları için dimension redcution mümkünmüdür? Mümkünse nasıl ve hangi katmanlarda uygulanabilir?

# %% [markdown]
# Mümkündür ve yapılır. Pooling katmanında uygulanır.

# %% [markdown]
# ### 12) 5,5 bir imaja 3,3 lük bir filtre uygulandığında stride=1 olacak şekilde elde edilen outputun boyutunun 5,5 olması niçin ne yapabiliriz?

# %% [markdown]
# ((n-f+2p)/s)+1 formülünde verilenleri yerine yazdığımızda ((5-3+2p)/1)+1 çıkar ve bu denklemi 5'e eşitlemeye çalışırsak. ((5-3+2p)/1)+1 = 5 ise 3+2p = 5 ve buradanda p=1 ortaya çıkar, yani padding=1 olmalı.
